# %%
import numpy as np

class SVM:
    def __init__(self, learning_rate=0.001, lambda_param=0.01, n_iters=1000):
        self.lr = learning_rate
        self.lambda_param = lambda_param # Регуляризация (C = 1/lambda)
        self.n_iters = n_iters
        self.w = None
        self.b = None

    def fit(self, X, y):
        # Превращаем метки 0/1 в -1/1
        y_ = np.where(y <= 0, -1, 1)
        n_samples, n_features = X.shape

        self.w = np.zeros(n_features)
        self.b = 0

        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                # Условие корректной классификации с учетом отступа
                condition = y_[idx] * (np.dot(x_i, self.w) - self.b) >= 1

                if condition:
                    # Только штраф за веса (L2 регуляризация)
                    self.w -= self.lr * (2 * self.lambda_param * self.w)
                else:
                    # Штраф за веса + ошибка классификации (Hinge Loss)
                    self.w -= self.lr * (2 * self.lambda_param * self.w - np.dot(x_i, y_[idx]))
                    self.b -= self.lr * y_[idx]

    def predict(self, X):
        approx = np.dot(X, self.w) - self.b
        return np.sign(approx)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
# Загрузка и подготовка данных
data = datasets.load_breast_cancer()
X, y = data.data, data.target

# SVM чувствителен к масштабу признаков
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Определение сетки параметров
param_grid = {
    'C': [0.1, 1, 10, 100],            # Параметр мягкого отступа
    'gamma': [1, 0.1, 0.01, 0.001],    # Коэффициент ядра (для rbf, poly, sigmoid)
    'kernel': ['rbf', 'poly', 'sigmoid']
}

# Поиск лучших параметров с кросс-валидацией
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=0, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'poly', 'sigmoid']})

# %%
# Визуализация тепловой карты (для ядра RBF)
# Извлекаем результаты и меняем форму для Heatmap
results = grid.cv_results_
# Выбираем только результаты, где kernel == 'rbf'
scores = results['mean_test_score'][results['param_kernel'] == 'rbf'].reshape(4, 4)

plt.figure(figsize=(8, 6))
sns.heatmap(scores, annot=True, xticklabels=param_grid['gamma'],
            yticklabels=param_grid['C'], cmap='viridis')
plt.xlabel('Gamma')
plt.ylabel('C')
plt.title('Accuracy Heatmap (RBF Kernel)')
plt.show()

print(f"Лучшие параметры: {grid.best_params_}")
print(f"Точность на тестовой выборке: {grid.score(X_test, y_test):.4f}")
# Out:
# Лучшие параметры: {'C': 100, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Точность на тестовой выборке: 0.9825

# %% [markdown]
# # Контекст:
# В астрономии классификация звезд — это классификация звезд на основе их спектральных характеристик. Схема классификации галактик, квазаров и звезд является одной из самых фундаментальных в астрономии. Ранняя каталогизация звезд и их распределения на небе привела к пониманию того, что они составляют нашу собственную галактику, и после того, как было установлено, что Андромеда является отдельной галактикой от нашей, многие галактики начали изучаться по мере создания более мощных телескопов. Цель этого спутника данных — классифицировать звезды, галактики и квазары на основе их спектральных характеристик.
#
# # Содержание:
#
# Данные состоят из 100 000 наблюдений космического пространства, выполненных в рамках проекта SDSS (Sloan Digital Sky Survey). Каждое наблюдение описывается 17 столбцами характеристик и 1 столбцом класса, который определяет, является ли оно звездой, галактикой или квазаром.

# %% [markdown]
# # Задание:
# Выполнить предобработку данных: обработать выбросы и пропущенные значения (если они есть)
#
# Использовать алгоритм SVM, построить тепловую карту для подбора значений gamma и C
#
# Вывести наилучшую точность модели

# %%
# obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS
# alpha = Right Ascension angle (at J2000 epoch)
# delta = Declination angle (at J2000 epoch)
# u = Ultraviolet filter in the photometric system
# g = Green filter in the photometric system
# r = Red filter in the photometric system
# i = Near Infrared filter in the photometric system
# z = Infrared filter in the photometric system
# run_ID = Run Number used to identify the specific scan
# rereun_ID = Rerun Number to specify how the image was processed
# cam_col = Camera column to identify the scanline within the run
# field_ID = Field number to identify each field
# spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class)
# class = object class (galaxy, star or quasar object)
# redshift = redshift value based on the increase in wavelength
# plate = plate ID, identifies each plate in SDSS
# MJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken
# fiber_ID = fiber ID that identifies the fiber that pointed the light at the focal plane in each observation

# %%
import pandas as pd

# %%
df = pd.read_csv('star_classification.csv').dropna()

# %%
# SVM чувствителен к масштабу признаков
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'poly', 'sigmoid']
}

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0

# [CV 3/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.750 total time=   0.2s
# [CV 5/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.755 total time=   0.2s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.949 total time=   0.2s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.922 total time=   0.2s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.924 total time=   0.2s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.950 total time=   0.3s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.950 total time=   0.2s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.661 total time=   0.3s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.659 total time=   0.4s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.659 total time=   0.3s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.656 total time=   0.3s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.662 total time=   0.4s
# [CV 2/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.896 total time=   0.2s
# [CV 1/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.935 total time=   0.3s
# [CV 3/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.910 total time=   0.2s
# [CV 4/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.921 total time=   0.2s
# [CV 5/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.910 total time=   0.2s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.901 total time=   0.3s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.865 total time=   0.3s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.858 total time=   0.3s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.904 total time=   0.4s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.975 total time=   8.2s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.866 total time=   0.3s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 1/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.877 total time=   0.2s
# [CV 2/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.836 total time=   0.3s
# [CV 3/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.844 total time=   0.3s
# [CV 4/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.882 total time=   0.3s
# [CV 5/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.849 total time=   0.3s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.955 total time=   0.2s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.954 total time=   0.2s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.955 total time=   0.2s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.956 total time=   0.3s
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.954 total time=  28.5s
# [CV 1/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.691 total time=   0.3s
# [CV 2/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.694 total time=   0.3s
# [CV 3/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.660 total time=   0.3s
# [CV 4/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.703 total time=   0.3s
# [CV 5/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.660 total time=   0.3s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.2s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.964 total time=   0.2s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.3s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.2s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.965 total time=   1.9s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.935 total time=   1.5s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.931 total time=   1.1s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.954 total time=   0.9s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.953 total time=   1.2s
# [CV 1/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.771 total time=   0.2s
# [CV 2/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.734 total time=   0.2s
# [CV 3/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.745 total time=   0.2s
# [CV 4/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.756 total time=   0.2s
# [CV 5/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.755 total time=   0.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.2s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.948 total time=   0.2s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.948 total time=   0.2s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.966 total time=   0.2s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.2s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.713 total time=   0.3s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.715 total time=   0.3s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.713 total time=   0.3s
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.948 total time=  41.1s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.714 total time=   0.3s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.721 total time=   0.3s
# [CV 1/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.880 total time=   0.2s
# [CV 3/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.861 total time=   0.1s
# [CV 2/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.855 total time=   0.1s
# [CV 5/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.853 total time=   0.1s
# [CV 4/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.895 total time=   0.2s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.954 total time=   0.3s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.924 total time=   0.3s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.925 total time=   0.3s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.946 total time=   0.3s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.934 total time=   0.2s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.600 total time=   0.4s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.600 total time=   0.4s
# [CV 1/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.934 total time=   0.3s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.600 total time=   0.3s
# [CV 2/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.910 total time=   0.2s
# [CV 3/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.902 total time=   0.3s
# [CV 4/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.927 total time=   0.2s
# [CV 5/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.909 total time=   0.2s
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.965 total time=  51.3s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.975 total time=  52.5s
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.958 total time=  52.8s
# [CV 5/5] END .......C=100, gamma=1, kernel=poly;, score=0.953 total time= 1.9min
# [CV 2/5] END .......C=100, gamma=1, kernel=poly;, score=0.956 total time= 2.8min
# [CV 4/5] END .......C=100, gamma=1, kernel=poly;, score=0.963 total time= 3.0min
# [CV 3/5] END .......C=100, gamma=1, kernel=poly;, score=0.946 total time= 3.3min
# [CV 1/5] END .......C=100, gamma=1, kernel=poly;, score=0.975 total time= 3.7min
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
# Визуализация тепловой карты (для ядра RBF)
# Извлекаем результаты и меняем форму для Heatmap
results = grid.cv_results_
# Выбираем только результаты, где kernel == 'rbf'
scores = results['mean_test_score'][results['param_kernel'] == 'rbf'].reshape(4, 4)

plt.figure(figsize=(8, 6))
sns.heatmap(scores, annot=True, xticklabels=param_grid['gamma'],
            yticklabels=param_grid['C'], cmap='viridis')
plt.xlabel('Gamma')
plt.ylabel('C')
plt.title('Accuracy Heatmap (RBF Kernel)')
plt.show()

print(f"Лучшие параметры: {grid.best_params_}")
print(f"Точность на тестовой выборке: {grid.score(X_test, y_test):.4f}")
# Out:
# Лучшие параметры: {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# Точность на тестовой выборке: 0.9570
